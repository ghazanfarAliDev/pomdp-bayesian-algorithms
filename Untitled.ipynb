# %%
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt
import pdb

# ---------------- MCTS Node ----------------
class MCTSNode:
    def __init__(self, state, parent=None, action_taken=None):
        self.state = np.array(state, dtype=np.float32)
        self.parent = parent
        self.action_taken = action_taken
        self.children = {}  # action -> child node
        self.visits = 0
        self.value = 0.0

    def is_leaf(self):
        return len(self.children) == 0

    def q_value(self):
        return self.value / self.visits if self.visits > 0 else 0

# ---------------- Rollout ----------------
def rollout_from_state(base_state, first_action, max_steps=200):
    env_sim = gym.make("CartPole-v1")
    obs, info = env_sim.reset()
    env_sim.unwrapped.state = np.array(base_state, dtype=np.float32)

    total_reward = 0.0
    obs, reward, terminated, truncated, info = env_sim.step(first_action)
    total_reward += reward
    done = terminated or truncated
    steps = 1

    while not done and steps < max_steps:
        a = random.choice([0, 1])
        obs, reward, terminated, truncated, info = env_sim.step(a)
        total_reward += reward
        done = terminated or truncated
        steps += 1

    env_sim.close()
    return total_reward


def mcts(env, root_state, n_simulations=50, max_rollout_steps=200):
    root = MCTSNode(root_state)
    print("================== MCTS =====================")
    for _ in range(n_simulations):
        node = root
        path = [node]

        # Selection
        while not node.is_leaf() and node.children:
            total_visits = sum(c.visits for c in node.children.values()) + 1
            best_score = -np.inf
            best_child = None
            for a, child in node.children.items():
                if child.visits == 0:
                    score = np.inf
                else:
                    score = child.q_value() + np.sqrt(2 * np.log(total_visits) / child.visits)
                if score > best_score:
                    # print("    Score = ",score)
                    # print("    best Score = ",best_score)
                    best_score = score
                    best_child = child
            node = best_child
            # print("This is the node of a best Child visits",node.visits)
            # print("This is the node of a best Child value",node.value)
            path.append(node)

        # Expansion of a tree
        if node.visits == 0:
            for action in [0, 1]:
                if action not in node.children:
                    # print("============Child Created==========")
                    node.children[action] = MCTSNode(state=node.state, parent=node, action_taken=action)
                    # print("Node Children = " ,node.children[action])

        # This is simulation Phase (Its Simulate the CartPole)
        first_action = random.choice([0, 1])
        reward = rollout_from_state(node.state, first_action, max_steps=max_rollout_steps)

        # This is The back propagation(This used for the back tracking leaf to the root)
        for n in path:
            n.visits += 1
            n.value += reward

    # Policy at root
    policy = {action: child.visits / root.visits for action, child in root.children.items()}
    return root, policy

def print_tree(node, depth=0, max_depth=3):
    if depth > max_depth:
        return
    indent = "  " * depth
    print(f"{indent}- Action:{node.action_taken} | Q={node.q_value():.2f}, V={node.visits}")
    for child in node.children.values():
        print_tree(child, depth + 1, max_depth)

def visualize_tree_matplotlib(root, max_depth=3):
    fig, ax = plt.subplots(figsize=(12, 8))

    positions = {}
    labels = {}
    colors = []

    def add_node(node, x, y, level=0):
        node_id = id(node)
        positions[node_id] = (x, y)
        labels[node_id] = f"Q:{node.q_value():.1f}\nV:{node.visits}"
        normalized = min(max(node.q_value() / 50, 0), 1)
        colors.append((1 - normalized, normalized, 0))  # Red -> Green

        if level < max_depth and node.children:
            n_children = len(node.children)
            dx = 1 / (n_children + 1)
            i = 1
            for child in node.children.values():
                child_x = x - 0.5 + i * dx
                child_y = y - 1
                ax.plot([x, child_x], [y, child_y], 'k-')
                # Add edge label (action)
                mid_x = (x + child_x) / 2
                mid_y = (y + child_y) / 2
                ax.text(mid_x, mid_y, str(child.action_taken), color='blue', fontsize=12)
                add_node(child, child_x, child_y, level + 1)
                i += 1

    add_node(root, 0, 0)

    for node_id, (x, y) in positions.items():
        ax.scatter(x, y, s=2500, c=[colors[list(positions.keys()).index(node_id)]])
        ax.text(x, y, labels[node_id], ha='center', va='center', fontsize=10)

    ax.axis('off')
    plt.show()

if __name__ == "__main__":
    env = gym.make("CartPole-v1")
    
    obs, info = env.reset()
    
    # pdb.set_trace()
    root_node, policy = mcts(env, env.unwrapped.state, n_simulations=50)

    print("Policy at root:", policy)
    print("\nMCTS Tree Values:")
    print_tree(root_node, max_depth=3)

    visualize_tree_matplotlib(root_node, max_depth=3)
# Out:
# ================== MCTS =====================
# Policy at root: {0: 0.96, 1: 0.02}
#
# MCTS Tree Values:
# - Action:None | Q=20.82, V=50
#   - Action:0 | Q=21.19, V=48
#     - Action:0 | Q=20.69, V=45
#       - Action:0 | Q=19.75, V=8
#       - Action:1 | Q=20.69, V=36
#     - Action:1 | Q=16.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#   - Action:1 | Q=9.00, V=1
#     - Action:0 | Q=0.00, V=0
#     - Action:1 | Q=0.00, V=0

# %%
import gymnasium as gym
import numpy as np
import random

# ---------------- MCTS Node ----------------
class MCTSNode:
    def __init__(self, state, parent=None, action_taken=None):
        self.state = np.array(state, dtype=np.float32)
        self.parent = parent
        self.action_taken = action_taken
        self.children = {}
        self.visits = 0
        self.value = 0.0

    def is_leaf(self):
        return len(self.children) == 0

    def q_value(self):
        return self.value / self.visits if self.visits > 0 else 0

# ---------------- Rollout ----------------
def rollout_from_state(base_state, first_action, max_steps=10):
    env_sim = gym.make("CartPole-v1")
    obs, info = env_sim.reset()
    env_sim.unwrapped.state = np.array(base_state, dtype=np.float32)

    total_reward = 0.0
    obs, reward, terminated, truncated, info = env_sim.step(first_action)
    total_reward += reward
    done = terminated or truncated
    steps = 1

    while not done and steps < max_steps:
        a = random.choice([0, 1])
        obs, reward, terminated, truncated, info = env_sim.step(a)
        total_reward += reward
        done = terminated or truncated
        steps += 1

    env_sim.close()
    return total_reward

# ---------------- Debug-style MCTS ----------------
def mcts_debug(env, root_state, n_simulations=5, max_rollout_steps=10):
    root = MCTSNode(root_state)

    print(f"Root state: {root.state}\n")

    for sim in range(n_simulations):
        print(f"--- Simulation {sim+1} ---")
        node = root
        path = [node]

        # --- Selection ---
        while not node.is_leaf() and node.children:
            total_visits = sum(c.visits for c in node.children.values()) + 1
            best_score = -np.inf
            best_child = None
            for a, child in node.children.items():
                score = child.q_value() + np.sqrt(2 * np.log(total_visits) / (child.visits + 1e-6))
                print(f"Child action={a}, Q={child.q_value():.2f}, visits={child.visits}, score={score:.2f}")
                if score > best_score:
                    best_score = score
                    best_child = child
            node = best_child
            path.append(node)
            print(f"Selected child action={node.action_taken}\n")

        # --- Expansion ---
        if node.visits == 0:
            for action in [0, 1]:
                if action not in node.children:
                    node.children[action] = MCTSNode(state=node.state, parent=node, action_taken=action)
            print(f"Node expanded: actions={list(node.children.keys())}\n")

        # --- Simulation / Rollout ---
        first_action = random.choice([0, 1])
        reward = rollout_from_state(node.state, first_action, max_steps=max_rollout_steps)
        print(f"Rollout reward={reward:.2f}\n")

        # --- Backpropagation ---
        print("Backpropagation:")
        for n in path:
            n.visits += 1
            n.value += reward
            print(f"Node action={n.action_taken}, Q={n.q_value():.2f}, V={n.visits}")
        print("\n")

    # Policy at root
    policy = {action: child.visits / root.visits for action, child in root.children.items()}
    print("Final Policy at root:", policy)
    return root

# ---------------- Run debug simulation ----------------
if __name__ == "__main__":
    env = gym.make("CartPole-v1")
    obs, info = env.reset()
    mcts_debug(env, env.unwrapped.state, n_simulations=5, max_rollout_steps=10)
# Out:
# Root state: [-0.02372547 -0.03270828  0.02050711  0.04720655]
#
# --- Simulation 1 ---
# Node expanded: actions=[0, 1]
#
# Rollout reward=10.00
#
# Backpropagation:
# Node action=None, Q=10.00, V=1
#
#
# --- Simulation 2 ---
# Child action=0, Q=0.00, visits=0, score=0.00
# Child action=1, Q=0.00, visits=0, score=0.00
# Selected child action=0
#
# Node expanded: actions=[0, 1]
#
# Rollout reward=10.00
#
# Backpropagation:
# Node action=None, Q=10.00, V=2
# Node action=0, Q=10.00, V=1
#
#
# --- Simulation 3 ---
# Child action=0, Q=10.00, visits=1, score=11.18
# Child action=1, Q=0.00, visits=0, score=1177.41
# Selected child action=1
#
# Node expanded: actions=[0, 1]
#
# Rollout reward=10.00
#
# Backpropagation:
# Node action=None, Q=10.00, V=3
# Node action=1, Q=10.00, V=1
#
#
# --- Simulation 4 ---
# Child action=0, Q=10.00, visits=1, score=11.48
# Child action=1, Q=10.00, visits=1, score=11.48
# Selected child action=0
#
# Child action=0, Q=0.00, visits=0, score=0.00
# Child action=1, Q=0.00, visits=0, score=0.00
# Selected child action=0
#
# Node expanded: actions=[0, 1]
#
# Rollout reward=10.00
#
# Backpropagation:
# Node action=None, Q=10.00, V=4
# Node action=0, Q=10.00, V=2
# Node action=0, Q=10.00, V=1
#
#
# --- Simulation 5 ---
# Child action=0, Q=10.00, visits=2, score=11.18
# Child action=1, Q=10.00, visits=1, score=11.67
# Selected child action=1
#
# Child action=0, Q=0.00, visits=0, score=0.00
# Child action=1, Q=0.00, visits=0, score=0.00
# Selected child action=0
#
# Node expanded: actions=[0, 1]
#
# Rollout reward=10.00
#
# Backpropagation:
# Node action=None, Q=10.00, V=5
# Node action=1, Q=10.00, V=2
# Node action=0, Q=10.00, V=1
#
#
# Final Policy at root: {0: 0.4, 1: 0.4}

# %%
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt

# ---------------- MCTS Node ----------------
class MCTSNode:
    def __init__(self, state, parent=None, action_taken=None):
        self.state = np.array(state, dtype=np.float32)
        self.parent = parent
        self.action_taken = action_taken
        self.children = {}
        self.visits = 0
        self.value = 0.0

    def is_leaf(self):
        return len(self.children) == 0

    def q_value(self):
        return self.value / self.visits if self.visits > 0 else 0

# ---------------- Rollout ----------------
def rollout_from_state(base_state, first_action, max_steps=10):
    env_sim = gym.make("CartPole-v1")
    obs, info = env_sim.reset()
    env_sim.unwrapped.state = np.array(base_state, dtype=np.float32)

    total_reward = 0.0
    obs, reward, terminated, truncated, info = env_sim.step(first_action)
    total_reward += reward
    done = terminated or truncated
    steps = 1

    while not done and steps < max_steps:
        a = random.choice([0, 1])
        obs, reward, terminated, truncated, info = env_sim.step(a)
        total_reward += reward
        done = terminated or truncated
        steps += 1

    env_sim.close()
    return total_reward

# ---------------- Step-by-step MCTS ----------------
def mcts_step_by_step(env, root_state, n_simulations=10, max_rollout_steps=10):
    root = MCTSNode(root_state)

    plt.ion()
    fig, ax = plt.subplots(figsize=(12, 8))

    for sim in range(n_simulations):
        node = root
        path = [node]

        # ----- SELECTION -----
        while not node.is_leaf() and node.children:
            total_visits = sum(c.visits for c in node.children.values()) + 1
            best_score = -np.inf
            best_child = None
            for a, child in node.children.items():
                score = child.q_value() + np.sqrt(2 * np.log(total_visits) / (child.visits + 1e-6))
                if score > best_score:
                    best_score = score
                    best_child = child
            node = best_child
            path.append(node)

        # ----- EXPANSION -----
        if node.visits == 0:
            for action in [0, 1]:
                if action not in node.children:
                    node.children[action] = MCTSNode(state=node.state, parent=node, action_taken=action)

        # ----- ROLLOUT -----
        first_action = random.choice([0, 1])
        reward = rollout_from_state(node.state, first_action, max_steps=max_rollout_steps)

        # ----- BACKPROPAGATION -----
        for n in path:
            n.visits += 1
            n.value += reward

        # ----- VISUALIZE AFTER EACH SIMULATION -----
        ax.clear()
        positions = {}
        labels = []
        colors = []

        def add_node(node, x, y, level=0):
            node_id = id(node)
            positions[node_id] = (x, y)
            labels.append(f"A:{node.action_taken}\nQ:{node.q_value():.1f}\nV:{node.visits}")
            normalized = min(max(node.q_value() / 50, 0), 1)
            colors.append((1 - normalized, normalized, 0))

            if level < 4 and node.children:
                n_children = len(node.children)
                dx = 1 / (n_children + 1)
                i = 1
                for child in node.children.values():
                    child_x = x - 0.5 + i * dx
                    child_y = y - 1
                    ax.plot([x, child_x], [y, child_y], 'k-')
                    mid_x = (x + child_x) / 2
                    mid_y = (y + child_y) / 2
                    ax.text(mid_x, mid_y, str(child.action_taken), color='blue', fontsize=12)
                    add_node(child, child_x, child_y, level + 1)
                    i += 1

        add_node(root, 0, 0)

        # Draw nodes
        for idx, node_id in enumerate(positions.keys()):
            x, y = positions[node_id]
            ax.scatter(x, y, s=2500, c=[colors[idx]])
            ax.text(x, y, labels[idx], ha='center', va='center', fontsize=10)

        ax.axis('off')
        ax.set_title(f"MCTS Tree - Simulation {sim+1} (Reward={reward:.1f})")
        plt.pause(0.5)

    plt.ioff()
    plt.show()
    return root

# ---------------- Print Tree ----------------
def print_tree(node, depth=0, max_depth=3):
    if depth > max_depth:
        return
    indent = "  " * depth
    print(f"{indent}- Action:{node.action_taken} | Q={node.q_value():.2f}, V={node.visits}")
    for child in node.children.values():
        print_tree(child, depth + 1, max_depth)

# ---------------- Run Example ----------------
if __name__ == "__main__":
    env = gym.make("CartPole-v1")
    obs, info = env.reset()
    root_node = mcts_step_by_step(env, env.unwrapped.state, n_simulations=10, max_rollout_steps=10)
    print("\nFinal Tree Values:")
    print_tree(root_node, max_depth=3)
# Out:
# Final Tree Values:
# - Action:None | Q=10.00, V=10
#   - Action:0 | Q=10.00, V=5
#     - Action:0 | Q=10.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#     - Action:1 | Q=10.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#   - Action:1 | Q=10.00, V=4
#     - Action:0 | Q=10.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#     - Action:1 | Q=10.00, V=1
#       - Action:0 | Q=0.00, V=0
#       - Action:1 | Q=0.00, V=0

# %%
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt

# ---------------- MCTS Node ----------------
class MCTSNode:
    def __init__(self, state, parent=None, action_taken=None):
        self.state = np.array(state, dtype=np.float32)
        self.parent = parent
        self.action_taken = action_taken
        self.children = {}  # action -> child node
        self.visits = 0
        self.value = 0.0

    def is_leaf(self):
        return len(self.children) == 0

    def q_value(self):
        return self.value / self.visits if self.visits > 0 else 0

# ---------------- Rollout ----------------
def rollout_from_state(base_state, first_action, max_steps=10):
    env_sim = gym.make("CartPole-v1")
    obs, info = env_sim.reset()
    env_sim.unwrapped.state = np.array(base_state, dtype=np.float32)

    total_reward = 0.0
    obs, reward, terminated, truncated, info = env_sim.step(first_action)
    total_reward += reward
    done = terminated or truncated
    steps = 1

    while not done and steps < max_steps:
        a = random.choice([0, 1])
        obs, reward, terminated, truncated, info = env_sim.step(a)
        total_reward += reward
        done = terminated or truncated
        steps += 1

    env_sim.close()
    return total_reward

# ---------------- Full MCTS Simulation ----------------
def mcts_full_trace(env, root_state, n_simulations=10, max_rollout_steps=10):
    root = MCTSNode(root_state)

    for sim in range(n_simulations):
        print(f"\n=== Simulation {sim+1} ===")
        node = root
        path = [node]

        # ----- SELECTION -----
        while not node.is_leaf() and node.children:
            total_visits = sum(c.visits for c in node.children.values()) + 1
            best_score = -np.inf
            best_child = None
            for a, child in node.children.items():
                score = child.q_value() + np.sqrt(2 * np.log(total_visits) / (child.visits + 1e-6))
                if score > best_score:
                    best_score = score
                    best_child = child
            node = best_child
            path.append(node)
            print(f"Selected Node Action={node.action_taken}, Visits={node.visits}, Q={node.q_value():.2f}")

        # ----- EXPANSION -----
        if node.visits == 0:
            for action in [0, 1]:
                if action not in node.children:
                    node.children[action] = MCTSNode(state=node.state, parent=node, action_taken=action)
                    print(f"Expanded: Created Child Node for Action={action}")

        # ----- ROLLOUT -----
        first_action = random.choice([0, 1])
        reward = rollout_from_state(node.state, first_action, max_steps=max_rollout_steps)
        print(f"Rollout Reward={reward}")

        # ----- BACKPROPAGATION -----
        for n in path:
            n.visits += 1
            n.value += reward
            print(f"Backprop: Node Action={n.action_taken}, Visits={n.visits}, Value={n.value}, Q={n.q_value():.2f}")

    # Policy at root
    policy = {action: child.visits / root.visits for action, child in root.children.items()}
    return root, policy

# ---------------- Print Tree ----------------
def print_tree(node, depth=0, max_depth=3):
    if depth > max_depth:
        return
    indent = "  " * depth
    print(f"{indent}- Action:{node.action_taken} | Q={node.q_value():.2f}, V={node.visits}")
    for child in node.children.values():
        print_tree(child, depth + 1, max_depth)

# ---------------- Run Full Trace ----------------
if __name__ == "__main__":
    env = gym.make("CartPole-v1")
    obs, info = env.reset()
    root_node, policy = mcts_full_trace(env, env.unwrapped.state, n_simulations=10, max_rollout_steps=10)

    print("\nFinal Policy at root:", policy)
    print("\nFinal MCTS Tree Values:")
    print_tree(root_node, max_depth=3)
# Out:
# === Simulation 1 ===
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 2 ===
# Selected Node Action=0, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=2, Value=20.0, Q=10.00
# Backprop: Node Action=0, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 3 ===
# Selected Node Action=1, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=3, Value=30.0, Q=10.00
# Backprop: Node Action=1, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 4 ===
# Selected Node Action=0, Visits=1, Q=10.00
# Selected Node Action=0, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=4, Value=40.0, Q=10.00
# Backprop: Node Action=0, Visits=2, Value=20.0, Q=10.00
# Backprop: Node Action=0, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 5 ===
# Selected Node Action=1, Visits=1, Q=10.00
# Selected Node Action=0, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=5, Value=50.0, Q=10.00
# Backprop: Node Action=1, Visits=2, Value=20.0, Q=10.00
# Backprop: Node Action=0, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 6 ===
# Selected Node Action=0, Visits=2, Q=10.00
# Selected Node Action=1, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=6, Value=60.0, Q=10.00
# Backprop: Node Action=0, Visits=3, Value=30.0, Q=10.00
# Backprop: Node Action=1, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 7 ===
# Selected Node Action=1, Visits=2, Q=10.00
# Selected Node Action=1, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=7, Value=70.0, Q=10.00
# Backprop: Node Action=1, Visits=3, Value=30.0, Q=10.00
# Backprop: Node Action=1, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 8 ===
# Selected Node Action=0, Visits=3, Q=10.00
# Selected Node Action=0, Visits=1, Q=10.00
# Selected Node Action=0, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=8, Value=80.0, Q=10.00
# Backprop: Node Action=0, Visits=4, Value=40.0, Q=10.00
# Backprop: Node Action=0, Visits=2, Value=20.0, Q=10.00
# Backprop: Node Action=0, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 9 ===
# Selected Node Action=1, Visits=3, Q=10.00
# Selected Node Action=0, Visits=1, Q=10.00
# Selected Node Action=0, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=9, Value=90.0, Q=10.00
# Backprop: Node Action=1, Visits=4, Value=40.0, Q=10.00
# Backprop: Node Action=0, Visits=2, Value=20.0, Q=10.00
# Backprop: Node Action=0, Visits=1, Value=10.0, Q=10.00
#
# === Simulation 10 ===
# Selected Node Action=0, Visits=4, Q=10.00
# Selected Node Action=1, Visits=1, Q=10.00
# Selected Node Action=0, Visits=0, Q=0.00
# Expanded: Created Child Node for Action=0
# Expanded: Created Child Node for Action=1
# Rollout Reward=10.0
# Backprop: Node Action=None, Visits=10, Value=100.0, Q=10.00
# Backprop: Node Action=0, Visits=5, Value=50.0, Q=10.00
# Backprop: Node Action=1, Visits=2, Value=20.0, Q=10.00
# Backprop: Node Action=0, Visits=1, Value=10.0, Q=10.00
#
# Final Policy at root: {0: 0.5, 1: 0.4}
#
# Final MCTS Tree Values:
# - Action:None | Q=10.00, V=10
#   - Action:0 | Q=10.00, V=5
#     - Action:0 | Q=10.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#     - Action:1 | Q=10.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#   - Action:1 | Q=10.00, V=4
#     - Action:0 | Q=10.00, V=2
#       - Action:0 | Q=10.00, V=1
#       - Action:1 | Q=0.00, V=0
#     - Action:1 | Q=10.00, V=1
#       - Action:0 | Q=0.00, V=0
#       - Action:1 | Q=0.00, V=0
